# %%
people = {"first": ["Corey", "Jane", "John"],
"last":["Scafer", "Doe", "Doe"]
, "email":["CoreyMSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first    last                    email
# 0  Corey  Scafer  CoreyMSchafer@gmail.com
# 1   Jane     Doe        JaneDoe@gmail.com
# 2   John     Doe        JohnDoe@gmail.com

# %%
df.set_index('email')
df.set_index('email', inplace=True)
#Both method do same task
# df
# Out:
#                          first    last
# email
# CoreyMSchafer@gmail.com  Corey  Scafer
# JaneDoe@gmail.com         Jane     Doe
# JohnDoe@gmail.com         John     Doe

# %%
df.loc['CoreyMSchafer@gmail.com']
# Out:
# first     Corey
# last     Scafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
#Method to reset index 
df.reset_index(inplace=True)
df
# Out:
#    index  first    last                    email
# 0      0  Corey  Scafer  CoreyMSchafer@gmail.com
# 1      1   Jane     Doe        JaneDoe@gmail.com
# 2      2   John     Doe        JohnDoe@gmail.com

# %%
df.iloc[0:3]
# Out:
#                      email  first    last
# 0  CoreyMSchafer@gmail.com  Corey  Scafer
# 1        JaneDoe@gmail.com   Jane     Doe
# 2        JohnDoe@gmail.com   John     Doe

# %%
df_public = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
df_schema = pd.read_csv('survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df_public.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %% [markdown]
# ## Filtering Data

# %%
# filt = df['last']=='Doe'
filt = (df['last'] == 'Doe') & (df['first'] == 'John')
df[filt]
# Out:
#                   first last
# email
# JohnDoe@gmail.com  John  Doe

# %%
df.loc[filt, 'email']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Shahz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File c:\Users\Shahz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Shahz\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'email'
#
# ...

# %%
countries  = ['Pakistan', 'United States of America']
filt_new = df_public['Country'].isin(countries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Semester 2\Programming For AI(python)\Practice\Pandas\pandas.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Practice/Pandas/pandas.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> countries  = ['Pakistan', 'United States of America']
# ----> <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Practice/Pandas/pandas.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> filt_new = df_public['Country'].isin(countries)
#
# NameError: name 'df_public' is not defined

# %%
df_public.loc[filt_new, 'Country']
# Out:
# ResponseId
# 5        United States of America
# 12       United States of America
# 13       United States of America
# 15       United States of America
# 27       United States of America
#                    ...
# 73232    United States of America
# 73241    United States of America
# 73255    United States of America
# 73265    United States of America
# 73266    United States of America
# Name: Country, Length: 14254, dtype: object

# %%
list_ = ['Python']
filt_er = df_public['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df_public[filt_er]
# Out:
#                                                    MainBranch  \
# ResponseId
# 3           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 12          I am not primarily a developer, but I write co...
# 15                             I am a developer by profession
# 17                             I am a developer by profession
# ...                                                       ...
# 73258                                   I am learning to code
# 73262                          I am a developer by profession
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
#
#                                                    Employment  \
# ResponseId
# 3                                         Employed, full-time
# 7                                          Student, part-time
# ...

# %% [markdown]
# ### Updating Rows and columns modifying data

# %%
df = pd.DataFrame(people)
df
# Out:
#    first    last                    email
# 0  Corey  Scafer  CoreyMSchafer@gmail.com
# 1   Jane     Doe        JaneDoe@gmail.com
# 2   John     Doe        JohnDoe@gmail.com

# %%
#Changing names of columns
print(df.columns)
df.columns = ['First_name', 'Last_name', 'Email']
df
# Out:
# Index(['First_name', 'Last_name', 'Email'], dtype='object')
#   First_name Last_name                    Email
# 0      Corey    Scafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey    Scafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
df.columns = df.columns.str.replace('_', ' ')
df

# %% [markdown]
# ## Pandas Date time series

# %%
import pandas as pd
df = pd.read_csv('ETH_1h.csv')
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
# d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d %I-%p')
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[4, 'Date'].day_name()
# Out:
# 'Friday'
