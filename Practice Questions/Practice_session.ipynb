# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
x = [1,3,4,8,10]
y = [3,5,8,0,11]
plt.plot(x,y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Basic line plot')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Generate sample data
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c='b', marker='o')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Scatter Plot')
plt.show()

# %%
import numpy as np
values = np.random.rand(10, 10)
plt.imshow(values, cmap='viridis')
plt.colorbar()
plt.title('Heatmap of 10X10 random values')
plt.show()
# Generate sample data
# data = np.random.rand(10, 10)

# # Create a heatmap
# plt.imshow(data, cmap='viridis')
# plt.colorbar()  # Add a colorbar for reference
# plt.title('Basic Heatmap')
# plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.image as mpimg
import cv2

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt

img = mpimg.imread('D:\Semester 2\Programming For AI(python)\Practice\Practice Questions\SunFlower_Image.jpg')
print(img.shape)
# rgb_image = img.convert('RGB')
plt.imshow(img)

plt.axis('on')
# Out:
# (563, 1000, 3)
# (-0.5, 999.5, 562.5, -0.5)

# %%
# YOUR CODE HERE


img2_new = img[50:320, 500:800]

plt.imshow(img2_new)
plt.axis('off')
# Out:
# (-0.5, 299.5, 269.5, -0.5)

# %%
# Load an image
image = cv2.imread('SunFlower_Image.jpg', cv2.IMREAD_GRAYSCALE)


img2_new = img[50:320, 500:800]
equalized_image = cv2.equalizeHist(img2_new)
# Plot the original and equalized images side by side
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.imshow(img2_new, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(122)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')
plt.axis('off')

plt.show()

# Create a figure with subplots for the images and histograms
fig, axes = plt.subplots(1, 2, figsize=(15, 5))


# Plot the histogram of the original image
axes[0].hist(img2_new.ravel(), bins=256, range=(0, 256), color='b')
axes[0].set_xlabel('Pixel Value')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Histogram of Original Image')

# Plot the histogram of the equalized image
axes[1].hist(equalized_image.ravel(), bins=256, range=(0, 256), color='b')
axes[1].set_xlabel('Pixel Value')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Histogram of Equalized Image')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# d:\Semester 2\Programming For AI(python)\Practice\Practice Questions\Practice_session.ipynb Cell 8 line 6
#       <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Practice/Practice%20Questions/Practice_session.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> image = cv2.imread('SunFlower_Image.jpg', cv2.IMREAD_GRAYSCALE)
#       <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Practice/Practice%20Questions/Practice_session.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> img2_new = img[50:320, 500:800]
# ----> <a href='vscode-notebook-cell:/d%3A/Semester%202/Programming%20For%20AI%28python%29/Practice/Practice%20Questions/Practice_session.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> equalized_image = cv2.equalizeHist(img2_new)
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image in color (you're currently loading it in grayscale)
image = cv2.imread('SunFlower_Image.jpg', cv2.IMREAD_COLOR)

# Check if the image loaded successfully
if image is not None:
    # Convert the color image to grayscale
    img_new = image[50:320, 500:800]
    img2_new = cv2.cvtColor(img_new, cv2.COLOR_BGR2GRAY)

    # Apply histogram equalization to the grayscale image
    equalized_image = cv2.equalizeHist(img2_new)

    # Plot the original and equalized images side by side
    plt.figure(figsize=(14, 5))
    plt.subplot(121)
    plt.imshow(img2_new, cmap='gray')
    plt.title('Original Image')
    plt.axis('on')

    plt.subplot(122)
    plt.imshow(equalized_image, cmap='gray')
    plt.title('Equalized Image')
    plt.axis('on')

    plt.show()

    # Create a figure with subplots for the images and histograms
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    # Plot the histogram of the original image
    axes[0].hist(img2_new.ravel(), bins=256, range=(0, 256), color='b')
    axes[0].set_xlabel('Pixel Value')
    axes[0].set_ylabel('Frequency')
    axes[0].set_title('Histogram of Original Image')

    # Plot the histogram of the equalized image
    axes[1].hist(equalized_image.ravel(), bins=256, range=(0, 256), color='b')
    axes[1].set_xlabel('Pixel Value')
    axes[1].set_ylabel('Frequency')
    axes[1].set_title('Histogram of Equalized Image')

    plt.tight_layout()
    plt.show()
else:
    print("Image not found or unable to load.")
